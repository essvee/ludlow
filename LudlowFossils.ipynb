# %%
import xmltodict
import pandas as pd
from convertbng.util import convert_bng, convert_lonlat

with open('input.xml') as fd:
    doc = xmltodict.parse(fd.read())

# %%
def parse_repro(repro_ref):
    if type(repro_ref) is str:
        repro_ref = [repro_ref]
        
    return [i.rsplit('\\', 1)[-1] for i in repro_ref if i != None]

# %%
def parse_stratigraphy_type(strat_t):
    if strat_t == None:
        return strat_t
    if isinstance(strat_t, dict): 
        return strat_t['text']['#text']
    else:
        return ", ".join(set([parse_stratigraphy_type(x) for x in strat_t]))

# %%
def parse_list(item):
    try:
        result = item if type(item) is str else "; ".join(item)
    except TypeError:
        result = item
    finally:
        return result

# %%
# 5x5 grid letters, missing I
alphabet = 'ABCDEFGHJKLMNOPQRSTUVWXYZ'

def grid2xy(false_easting, false_northing, gridsizes, grid_ref):
    '''Convert grid reference to coordinates'''
    # false easting and northing
    easting = -false_easting
    northing = -false_northing

    # convert letter(s) to easting and northing offset
    for n in range(0, len(gridsizes)):
        letter = grid_ref[n]
        idx = alphabet.index(letter)
        col = (idx % 5)
        row = 4 - int((idx / 5))
        easting += (col * gridsizes[n])
        
        northing += (row * gridsizes[n])

  # numeric components of grid reference
    grid_ref = grid_ref[len(gridsizes):] # remove the letters
    e = '{:0<5}'.format(grid_ref[0:int(len(grid_ref)/2)]) 
    e = '{}.{}'.format(e[0:5],e[5:])
    
    n = '{:0<5}'.format(grid_ref[int(len(grid_ref)/2):])
    n = '{}.{}'.format(n[0:5],n[5:])
    
    easting += float(e)
    northing += float(n)
    
    return easting, northing

def british2xy(grid_ref):
    if 'S' not in grid_ref:
        return
    else:
        false_easting = 1000000
        false_northing = 500000
        gridsizes = [500000, 100000]
        return grid2xy(false_easting, false_northing, gridsizes, grid_ref)

def irish2xy(grid_ref):
    false_easting = 0
    false_northing = 0
    gridsizes = [100000]
    return grid2xy(false_easting, false_northing, gridsizes, grid_ref)

# %%
adlib_records = doc['adlibXML']['recordList']['record']

results = []

for n in adlib_records:
    results.append({
        'priref': n['priref'][0],
        'repro_ref': parse_repro(n['reproduction.reference']),
        'object_number': n['object_number'],
        'object_name': parse_list(n.get('object_name')),
        'os_gridref': n.get('field_coll.gridref', 'unknown'),
        'strat_unit': parse_list(n.get('stratigraphy.unit', [])),
        'strat_type': parse_stratigraphy_type(n.get('stratigraphy.type')),
        'taxonomy': parse_list(n.get('taxonomy.scientific_name')),
        'description': n['description'],
        'coll_name': parse_list(n.get('field_coll.name')),
        'coll_place': parse_list(n.get('field_coll.place')),
        'coords': british2xy(n.get('field_coll.gridref', 'unknown'))
    })

df = pd.DataFrame(results)

# %%
df.head()
# Out:
#   coll_name                         coll_place                coords  \
# 0   unknown  Marshwood; Marshbrook; Shropshire  (344000.0, 289000.0)
# 1   unknown  Marshwood; Marshbrook; Shropshire  (344000.0, 289000.0)
# 2   unknown                         Marshbrook  (344000.0, 289000.0)
# 3   unknown                   Cheney Longville  (341000.0, 285000.0)
# 4   unknown                          Marshwood                  None
#
#                                          description object_name  \
# 0  Fossilised shell remains of the Ordovician bra...  Brachiopod
# 1  Fossilised shell remains of the Ordovician bra...  Brachiopod
# 2  Fossilised remains of Ordovician brachiopod, S...  Brachiopod
# 3  Fossilised remains of single valve of Ordovici...  Brachiopod
# 4  Fossilised remains of shell of the Ordovician ...  Brachiopod
#
#   object_number os_gridref  priref          repro_ref  \
# 0   G.00055.001     SO4489   51824  [G.00055.001.jpg]
# 1   G.00055.002     SO4489  655139  [G.00055.002.jpg]
# 2       G.00093     SO4489   51902      [G.00093.jpg]
# 3       G.00094     SO4185   51903      [G.00094.jpg]
# 4   G.00096.002    unknown   54696  [G.00096.002.jpg]
#
#                               strat_type  \
# 0  Chronostratigraphy, Lithostratigraphy
# 1  Chronostratigraphy, Lithostratigraphy
# 2                     Chronostratigraphy
# 3                     Chronostratigraphy
# 4  Chronostratigraphy, Lithostratigraphy
#
#                                           strat_unit             taxonomy
# 0  Ordovician; Caradoc Series; Marshbrookian Stag...    Dalmanella unguis
# 1  Ordovician; Caradoc Series; Marshbrookian Stag...    Dalmanella unguis
# 2  Ordovician Period; Caradoc Series; Longvillian...  Strophomena grandis
# 3  Ordovician Period; Caradoc Series; Aeronian St...        Kjaerina typa
# 4  Ordovician Period; Caradoc Series; Cheney Long...    Dalmanella wattsi

# %%
df[['easting', 'northing']] = df['coords'].apply(pd.Series)

# %%
copy = df[['easting', 'northing']].copy()
copy.dropna(subset=['easting'], how='all', inplace = True)
copy[:1]
# Out:
#     easting  northing
# 0  344000.0  289000.0

# %%
copy_e = list(copy['easting'].values)
copy_n = list(copy['northing'].values)

copy['long'], copy['lat'] = convert_lonlat(copy_e, copy_n)

# %%
print(type(copy))
df['lat'] = pd.Series(copy['lat'], index=df.index)
df['long'] = pd.Series(copy['long'], index=df.index)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#                                       coll_name  \
# 0                                       unknown
# 1                                       unknown
# 2                                       unknown
# 3                                       unknown
# 4                                       unknown
# 5                                       unknown
# 6                                       unknown
# 7                                       unknown
# 8                             Lloyd, Dr. Thomas
# 9                                       unknown
# 10                                Lightbody, R.
# 11                                      unknown
# 12                      Pardoe, H.; Marston, A.
# 13                        Stackhouse-Acton, Mrs
# 14                                      unknown
# 15                                      unknown
# 16                                      unknown
# 17                                      unknown
# 18                                      unknown
# 19                                      unknown
# 20                                      unknown
# 21                                      unknown
# 22                                      unknown
# 23                                      unknown
# 24                                      unknown
# 25                                      unknown
# 26                        Moore, R.G.; Bell, P.
# 27                                      unknown
# 28                                      unknown
# 29                                 Norton, W.J.
# ...                                         ...
# 1463                                    unknown
# 1464                             Toghill, Peter
# 1465                             Toghill, Peter
# 1466                                    unknown
# 1467                             Toghill, Peter
# 1468                                    unknown
# 1469                             Whittard, W.F.
# 1470                             Buddicom, R.A.
# 1471               Wyley, Canon William Kiteley
# 1472                                    unknown
# 1473                                    unknown
# 1474                                    unknown
# 1475                                    unknown
# 1476                                    unknown
# 1477                                    unknown
# 1478                                    unknown
# 1479                                    unknown
# 1480                                    unknown
# 1481                                    unknown
# 1482               Wyley, Canon William Kiteley
# 1483  Cobbold, Edgar Stirling (DSc, AMICE, FGS)
# 1484  Cobbold, Edgar Stirling (DSc, AMICE, FGS)
# 1485                             Buddicom, R.A.
# 1486                             Buddicom, R.A.
# 1487                             Buddicom, R.A.
# 1488                             Buddicom, R.A.
# 1489                             Buddicom, R.A.
# 1490  Cobbold, Edgar Stirling (DSc, AMICE, FGS)
# 1491  Cobbold, Edgar Stirling (DSc, AMICE, FGS)
# 1492                             Buddicom, R.A.
#
#                              coll_place                coords  \
# 0     Marshwood; Marshbrook; Shropshire  (344000.0, 289000.0)
# 1     Marshwood; Marshbrook; Shropshire  (344000.0, 289000.0)
# 2                            Marshbrook  (344000.0, 289000.0)
# 3                      Cheney Longville  (341000.0, 285000.0)
# 4                             Marshwood                  None
# 5                            Meadowtown                  None
# 6                               Unknown                  None
# 7                               Unknown                  None
# 8                               Unknown                  None
# 9                               Unknown                  None
# 10                           Whitcliffe  (350000.0, 274000.0)
# 11                              Unknown                  None
# 12                           Shelderton  (340000.0, 277000.0)
# 13                         Caer Caradoc                  None
# 14                              Unknown                  None
# 15                             Mocktree  (342000.0, 276000.0)
# 16                             Mocktree  (342000.0, 276000.0)
# 17                             Mocktree  (342000.0, 276000.0)
# 18                             Mocktree  (342000.0, 276000.0)
# 19                             Mocktree  (342000.0, 276000.0)
# 20                             Mocktree  (342000.0, 276000.0)
# 21                             Mocktree  (342000.0, 276000.0)
# 22                           Diddlebury  (350000.0, 285000.0)
# 23                           Shelderton  (340000.0, 277000.0)
# 24                              Unknown                  None
# 25                          Ludlow Town  (351000.0, 274000.0)
# 26                           Whitcliffe  (350000.0, 274000.0)
# 27                      Ludlow district  (350000.0, 274000.0)
# 28                          Church Hill  (341000.0, 273000.0)
# 29                          Ludlow Town  (351000.0, 274000.0)
# ...                                 ...                   ...
# 1463                    Blodwell Quarry                  None
# 1464                           Stapeley                  None
# 1465                           Cornwall                  None
# 1466                            Unknown                  None
# 1467                           Cornwall                  None
# 1468                            Unknown                  None
# 1469             The Bridges, Longmynd.                  None
# 1470                          Horderley                  None
# 1471                         Marshbrook  (344000.0, 289000.0)
# 1472                             Dudley                  None
# 1473                           Morville                  None
# 1474                      Coalbrookdale                  None
# 1475                      Coalbrookdale                  None
# 1476                          Grinshill                  None
# 1477                Longden, Shropshire                  None
# 1478                         Shropshire                  None
# 1479                            Unknown                  None
# 1480                            Unknown                  None
# 1481                       Overley Hill                  None
# 1482                           Garmston                  None
# 1483              Harnage Grange Quarry                  None
# 1484              Harnage Grange Quarry                  None
# 1485                               None                  None
# 1486                 Onny River section                  None
# 1487                 Onny River section                  None
# 1488                 Onny River section                  None
# 1489                 Onny River section                  None
# 1490                            Gretton                  None
# 1491                            Gretton                  None
# 1492                          Horderley                  None
#
#                                             description  \
# 0     Fossilised shell remains of the Ordovician bra...
# 1     Fossilised shell remains of the Ordovician bra...
# 2     Fossilised remains of Ordovician brachiopod, S...
# 3     Fossilised remains of single valve of Ordovici...
# 4     Fossilised remains of shell of the Ordovician ...
# 5     Fossilised remains of the Ordovician graptolit...
# 6     Fossilised remains of the Silurian tabulate, c...
# 7     Fossilised remains of the Silurian rugose cora...
# ...                                              ...       ...       ...
# 1463                                     Keratophyre       NaN       NaN
# 1464                                            Tuff       NaN       NaN
# 1465                                           Slate       NaN       NaN
# 1466                                          Schist       NaN       NaN
# 1467                                           Slate       NaN       NaN
# 1468                                            None       NaN       NaN
# 1469                             Pentamerus oblongus       NaN       NaN
# 1470                                     Lingula sp.       NaN       NaN
# 1471                              Kjaerina bipartita  344000.0  289000.0
# 1472                                       Limestone       NaN       NaN
# 1473                                   Pteraspis sp.       NaN       NaN
# 1474                        Spirifera pennystenensis       NaN       NaN
# 1475                        Spirifera pennystenensis       NaN       NaN
# 1476                          Rhynchosaurus articeps       NaN       NaN
# 1477                              Pecopteris miltoni       NaN       NaN
# 1478                              Acervularia ananas       NaN       NaN
# 1479                                            None       NaN       NaN
# 1480                                         NODULES       NaN       NaN
# 1481                                            None       NaN       NaN
# 1482                                   Hyolithos sp.       NaN       NaN
# 1483                              Heterorthis patera       NaN       NaN
# 1484                              Heterorthis patera       NaN       NaN
# 1485                                   Onnia superba       NaN       NaN
# 1486                                   Onnia superba       NaN       NaN
# 1487                                   Onnia superba       NaN       NaN
# 1488                                   Onnia superba       NaN       NaN
# 1489                                   Onnia superba       NaN       NaN
# 1490            Calymene sp.; Resserella paracyclica       NaN       NaN
# 1491                          Resserella paracyclica       NaN       NaN
# 1492  Reuschella horderleyensis; Dinorthis flabellum       NaN       NaN
#
#             lat      long
# 0     52.496032 -2.826285
# 1     52.496032 -2.826285
# 2     52.496032 -2.826285
# 3     52.459759 -2.869758
# 4           NaN       NaN
# 5           NaN       NaN
# 6           NaN       NaN
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10    52.361775 -2.735666
# 11          NaN       NaN
# 12    52.387737 -2.883036
# 13          NaN       NaN
# 14          NaN       NaN
# 15    52.378964 -2.853479
# 16    52.378964 -2.853479
# 17    52.378964 -2.853479
# 18    52.378964 -2.853479
# 19    52.378964 -2.853479
# 20    52.378964 -2.853479
# 21    52.378964 -2.853479
# 22    52.460659 -2.737314
# 23    52.387737 -2.883036
# 24          NaN       NaN
# 25    52.361866 -2.720983
# 26    52.361775 -2.735666
# 27    52.361775 -2.735666
# 28    52.351889 -2.867639
# 29    52.361866 -2.720983
# ...         ...       ...
# 1463        NaN       NaN
# 1464        NaN       NaN
# 1465        NaN       NaN
# 1466        NaN       NaN
# 1467        NaN       NaN
# 1468        NaN       NaN
# 1469        NaN       NaN
# 1470        NaN       NaN
# 1471  52.496032 -2.826285
# 1472        NaN       NaN
# 1473        NaN       NaN
# 1474        NaN       NaN
# 1475        NaN       NaN
# 1476        NaN       NaN
# 1477        NaN       NaN
# 1478        NaN       NaN
# 1479        NaN       NaN
# 1480        NaN       NaN
# 1481        NaN       NaN
# 1482        NaN       NaN
# 1483        NaN       NaN
# 1484        NaN       NaN
# 1485        NaN       NaN
# 1486        NaN       NaN
# 1487        NaN       NaN
# 1488        NaN       NaN
# 1489        NaN       NaN
# 1490        NaN       NaN
# 1491        NaN       NaN
# 1492        NaN       NaN
#
# [1493 rows x 16 columns]
